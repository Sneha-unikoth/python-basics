# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a="sneha"
print(a)
# Out:
# sneha

# %%
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-85111a3ab660> in <cell line: 1>()
# ----> 1 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
c="acb"
print(a+c)
# Out:
# snehaacb

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
a=input()
b=input()
print(a+b)
# Out:
# 12
# 11
# 1211

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(type(b))
# Out:
# <class 'str'>

# %%
a=int(input)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d9b5624d4c3a> in <cell line: 1>()
# ----> 1 a=int(input)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'method'

# %%
a=int(input())
b=int(input())
print(a+b)
# Out:
# 2
# 3
# 5

# %%
a=int(input("enter your first number"))
b=int(input("enter your second number"))
print(a+b)
# Out:
# enter your first number2
# enter your second number3
# 5

# %% [markdown]
# string

# %%
a="sneha"
print(len(a))
# Out:
# 5

# %%
str1="hellogoodmorning"
str1.capitalize()
# Out:
# 'Hellogoodmorning'

# %%
str2="hello good morning hai"
str2.title()
# Out:
# 'Hello Good Morning Hai'

# %%
str2.upper()
# Out:
# 'HELLO GOOD MORNING HAI'

# %%
str2.lower()
# Out:
# 'hello good morning hai'

# %%
str2.count("o")
# Out:
# 4

# %%
str2.count("n")
# Out:
# 2

# %%
str2.count("morning")
# Out:
# 1

# %%
str2.find("good")
# Out:
# 6
